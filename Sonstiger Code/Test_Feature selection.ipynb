# %%
import pandas as pd
import h5py
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
phase0 = pd.DataFrame(pd.read_hdf("C:\MessdatenStoeckach\\2017-03-02\phase_0_2017-03-02.h5",key='tenperiodtable', mode='r'))

# %%
phase0
# Out:
#                 N          P        PF          S       freq      rms_i  \
# 0       40.179317 -10.607196 -0.255251  41.555870  49.976013  53.648041
# 1       38.660263 -10.655907 -0.265721  40.101925  49.977509  53.619755
# 2       38.916111 -10.543956 -0.261512  40.319210  49.978508  53.604694
# 3       38.448627 -10.536503 -0.264297  39.866211  49.976513  53.637009
# 4       38.960796 -10.551473 -0.261406  40.364307  49.978008  53.629028
# ...           ...        ...       ...        ...        ...        ...
# 168057   0.302044  -0.020904 -0.069043   0.302766  50.044037   1.438296
# 168058   0.309757  -0.024046 -0.077395   0.310689  50.044037   1.448914
# 168059   0.300987  -0.024360 -0.080670   0.301971  50.043537   1.450690
# 168060   0.326494  -0.023102 -0.070580   0.327310  50.041534   1.455666
# 168061   0.326224  -0.024006 -0.073389   0.327106  50.042538   1.447685
#
#            rms_u       thd_i      thd_u     timestamp
# ...

# %%
with h5py.File("C:\MessdatenStoeckach\\2017-03-02\harmonics_phase_1_2017-03-02.h5", "r") as f:
    dset = np.array(f["tenperiodtable"])
    phase1harmonics = pd.DataFrame(dset['harmonics_i'])

# %%
phase1harmonics
# Out:
#             0         1         2         3         4         5         6     \
# 0       0.036987  0.759766  0.040009  0.721191  0.024002  0.085022  0.012001
# 1       0.024994  0.766113  0.020004  0.711914  0.020996  0.096985  0.028000
# 2       0.020004  0.764160  0.037994  0.712891  0.032990  0.091980  0.031006
# 3       0.040009  0.757812  0.014999  0.711914  0.024994  0.088989  0.020004
# 4       0.028000  0.765137  0.041992  0.717773  0.032013  0.078979  0.020996
# ...          ...       ...       ...       ...       ...       ...       ...
# 168057  0.013000  0.646973  0.010002  0.509766  0.010002  0.264893  0.004002
# 168058  0.011002  0.649902  0.009003  0.512207  0.008003  0.268066  0.005001
# 168059  0.020004  0.652832  0.016006  0.509766  0.014999  0.271973  0.007000
# 168060  0.013000  0.653809  0.009003  0.514160  0.012001  0.270996  0.005001
# 168061  0.014999  0.648926  0.009003  0.508789  0.011002  0.269043  0.007000
#
# ...

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector = VarianceThreshold(0.1)
phase1harmonics_reduced = selector.fit_transform(phase1harmonics)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-e891ef5bcf8f> in <module>
#       1 selector = VarianceThreshold(0.1)
# ----> 2 phase1harmonics_reduced = selector.fit_transform(phase1harmonics)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_variance_threshold.py in fit(self, X, y)
#      90             if X.shape[0] == 1:
#      91                 msg += " (X contains only one sample)"
# ---> 92             raise ValueError(msg.format(self.threshold))
#      93
# ...

# %%
phase1harmonics_reduced.shape
# Out:
# (168062, 2998)
